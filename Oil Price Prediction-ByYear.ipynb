# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
plt.style.use('seaborn')

# %% [markdown]
# # IMPORTING DATASET

# %%
dataset=pd.read_csv('brent-year.csv')
dataset
# Out:
#           Date   Price
# 0   1987-06-30   18.53
# 1   1988-06-30   14.91
# 2   1989-06-30   18.23
# 3   1990-06-30   23.76
# 4   1991-06-30   20.04
# 5   1992-06-30   19.32
# 6   1993-06-30   17.01
# 7   1994-06-30   15.86
# 8   1995-06-30   17.02
# 9   1996-06-30   20.64
# 10  1997-06-30   19.11
# 11  1998-06-30   12.76
# 12  1999-06-30   17.90
# 13  2000-06-30   28.66
# 14  2001-06-30   24.46
# 15  2002-06-30   24.99
# 16  2003-06-30   28.85
# 17  2004-06-30   38.26
# 18  2005-06-30   54.57
# 19  2006-06-30   65.16
# 20  2007-06-30   72.44
# 21  2008-06-30   96.94
# 22  2009-06-30   61.74
# 23  2010-06-30   79.61
# 24  2011-06-30  111.26
# 25  2012-06-30  111.63
# 26  2013-06-30  108.56
# 27  2014-06-30   98.97
# 28  2015-06-30   52.32
# 29  2016-06-30   43.64
# 30  2017-06-30   54.13
# 31  2018-06-30   71.34
# 32  2019-06-30   64.30

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.describe()
# Out:
#             Price
# count   33.000000
# mean    46.270303
# std     32.242267
# min     12.760000
# 25%     19.110000
# 50%     28.850000
# 75%     65.160000
# max    111.630000

# %%
dataset.info
# Out:
# <bound method DataFrame.info of           Date   Price
# 0   1987-06-30   18.53
# 1   1988-06-30   14.91
# 2   1989-06-30   18.23
# 3   1990-06-30   23.76
# 4   1991-06-30   20.04
# 5   1992-06-30   19.32
# 6   1993-06-30   17.01
# 7   1994-06-30   15.86
# 8   1995-06-30   17.02
# 9   1996-06-30   20.64
# 10  1997-06-30   19.11
# 11  1998-06-30   12.76
# 12  1999-06-30   17.90
# 13  2000-06-30   28.66
# 14  2001-06-30   24.46
# 15  2002-06-30   24.99
# 16  2003-06-30   28.85
# 17  2004-06-30   38.26
# 18  2005-06-30   54.57
# 19  2006-06-30   65.16
# 20  2007-06-30   72.44
# 21  2008-06-30   96.94
# 22  2009-06-30   61.74
# 23  2010-06-30   79.61
# 24  2011-06-30  111.26
# 25  2012-06-30  111.63
# 26  2013-06-30  108.56
# 27  2014-06-30   98.97
# 28  2015-06-30   52.32
# 29  2016-06-30   43.64
# 30  2017-06-30   54.13
# 31  2018-06-30   71.34
# 32  2019-06-30   64.30>

# %% [markdown]
# # DATA VISUALIZATION

# %%
df=pd.DataFrame(dataset)
df['day']=pd.DatetimeIndex(df['Date']).day
print(df)
# Out:
#           Date   Price  day
# 0   1987-06-30   18.53   30
# 1   1988-06-30   14.91   30
# 2   1989-06-30   18.23   30
# 3   1990-06-30   23.76   30
# 4   1991-06-30   20.04   30
# 5   1992-06-30   19.32   30
# 6   1993-06-30   17.01   30
# 7   1994-06-30   15.86   30
# 8   1995-06-30   17.02   30
# 9   1996-06-30   20.64   30
# 10  1997-06-30   19.11   30
# 11  1998-06-30   12.76   30
# 12  1999-06-30   17.90   30
# 13  2000-06-30   28.66   30
# 14  2001-06-30   24.46   30
# 15  2002-06-30   24.99   30
# 16  2003-06-30   28.85   30
# 28  2015-06-30   52.32   30      6  2015
# 29  2016-06-30   43.64   30      6  2016
# 30  2017-06-30   54.13   30      6  2017
# 31  2018-06-30   71.34   30      6  2018
# 32  2019-06-30   64.30   30      6  2019

# %%
x=dataset.iloc[:,2:5]
x
# Out:
#     day  month  year
# 0    30      6  1987
# 1    30      6  1988
# 2    30      6  1989
# 3    30      6  1990
# 4    30      6  1991
# 5    30      6  1992
# 6    30      6  1993
# 7    30      6  1994
# 8    30      6  1995
# 9    30      6  1996
# 10   30      6  1997
# 11   30      6  1998
# 12   30      6  1999
# 13   30      6  2000
# 14   30      6  2001
# 15   30      6  2002
# 16   30      6  2003
# 17   30      6  2004
# 18   30      6  2005
# 19   30      6  2006
# 20   30      6  2007
# 21   30      6  2008
# 22   30      6  2009
# 23   30      6  2010
# 24   30      6  2011
# 25   30      6  2012
# 26   30      6  2013
# 27   30      6  2014
# 28   30      6  2015
# 29   30      6  2016
# 30   30      6  2017
# 31   30      6  2018
# 32   30      6  2019

# %%
y=dataset.iloc[:,1:2]
y
# Out:
#      Price
# 0    18.53
# 1    14.91
# 2    18.23
# 3    23.76
# 4    20.04
# 5    19.32
# 6    17.01
# 7    15.86
# 8    17.02
# 9    20.64
# 10   19.11
# 11   12.76
# 12   17.90
# 13   28.66
# 14   24.46
# 15   24.99
# 16   28.85
# 17   38.26
# 18   54.57
# 19   65.16
# 20   72.44
# 21   96.94
# 22   61.74
# 23   79.61
# 24  111.26
# 25  111.63
# 26  108.56
# 27   98.97
# 28   52.32
# 29   43.64
# 30   54.13
# 31   71.34
# 32   64.30

# %%
x=df['year']
y=df['Price']
sns.regplot(x,y,data=dataset)

# %%
plt.bar(df['year'],df['Price'],align='center')
plt.ylabel("Oil Prices")
plt.xlabel("Year")
plt.title("Year vs Oil Prices")
# Out:
# Text(0.5, 1.0, 'Year vs Oil Prices')

# %% [markdown]
# # TAKING CARE OF MISSING DATA

# %%
dataset.isnull().any()
# Out:
# Date     False
# Price    False
# day      False
# month    False
# year     False
# dtype: bool

# %%
x=dataset.iloc[:,2:5].values
x
# Out:
# array([[  30,    6, 1987],
#        [  30,    6, 1988],
#        [  30,    6, 1989],
#        [  30,    6, 1990],
#        [  30,    6, 1991],
#        [  30,    6, 1992],
#        [  30,    6, 1993],
#        [  30,    6, 1994],
#        [  30,    6, 1995],
#        [  30,    6, 1996],
#        [  30,    6, 1997],
#        [  30,    6, 1998],
#        [  30,    6, 1999],
#        [  30,    6, 2000],
#        [  30,    6, 2001],
#        [  30,    6, 2002],
#        [  30,    6, 2003],
#        [  30,    6, 2004],
#        [  30,    6, 2005],
#        [  30,    6, 2006],
#        [  30,    6, 2007],
#        [  30,    6, 2008],
#        [  30,    6, 2009],
#        [  30,    6, 2010],
#        [  30,    6, 2011],
#        [  30,    6, 2012],
#        [  30,    6, 2013],
#        [  30,    6, 2014],
#        [  30,    6, 2015],
#        [  30,    6, 2016],
#        [  30,    6, 2017],
#        [  30,    6, 2018],
#        [  30,    6, 2019]], dtype=int64)

# %%
y=dataset.iloc[:,1:2].values
y
# Out:
# array([[ 18.53],
#        [ 14.91],
#        [ 18.23],
#        [ 23.76],
#        [ 20.04],
#        [ 19.32],
#        [ 17.01],
#        [ 15.86],
#        [ 17.02],
#        [ 20.64],
#        [ 19.11],
#        [ 12.76],
#        [ 17.9 ],
#        [ 28.66],
#        [ 24.46],
#        [ 24.99],
#        [ 28.85],
#        [ 38.26],
#        [ 54.57],
#        [ 65.16],
#        [ 72.44],
#        [ 96.94],
#        [ 61.74],
#        [ 79.61],
#        [111.26],
#        [111.63],
#        [108.56],
#        [ 98.97],
#        [ 52.32],
#        [ 43.64],
#        [ 54.13],
#        [ 71.34],
#        [ 64.3 ]])

# %% [markdown]
# LABEL ENCODING and ONE HOT ENCODING isn't required as the dataset is in digits and not many categories.

# %% [markdown]
# # SPLITTING DATA INTO TRAIN AND TEST

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
x_train
# Out:
# array([[  30,    6, 2016],
#        [  30,    6, 2010],
#        [  30,    6, 2002],
#        [  30,    6, 1995],
#        [  30,    6, 2000],
#        [  30,    6, 2017],
#        [  30,    6, 1992],
#        [  30,    6, 2001],
#        [  30,    6, 2015],
#        [  30,    6, 2009],
#        [  30,    6, 1988],
#        [  30,    6, 1999],
#        [  30,    6, 1993],
#        [  30,    6, 1991],
#        [  30,    6, 2005],
#        [  30,    6, 2008],
#        [  30,    6, 2006],
#        [  30,    6, 1996],
#        [  30,    6, 1994],
#        [  30,    6, 2018],
#        [  30,    6, 2014],
#        [  30,    6, 1990],
#        [  30,    6, 1987]], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# # TRAINING AND TESTING THE MODEL

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor(random_state=0,criterion="mse",max_depth=10) #default parameter is MSE so need not give

dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=10, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=0, splitter='best')

# %%
import pickle
pickle.dump(dt,open('decision1.pkl','wb'))

# %%
y_predict=dt.predict(x_test)
y_predict
# Out:
# array([17.9 , 96.94, 79.61, 54.57, 14.91, 98.97, 98.97, 24.99, 20.64,
#        71.34])

# %% [markdown]
# # EVALUATION

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,dt.predict(x_test))
# Out:
# 0.8506515381503867

# %%
r2_score(y_train,dt.predict(x_train))
# Out:
# 1.0

# %%
ng_fft = np.fft.fft(np.asarray(dataset['Price'].tolist()))
fft_df = pd.DataFrame({'fft':ng_fft})
fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))

plt.figure(figsize=(14, 7), dpi=100)
fft_list = np.asarray(fft_df['fft'].tolist())
for num_ in [3, 6, 9, 100]:
    fft_list_m10= np.copy(fft_list); fft_list_m10[num_:-num_]=0
    plt.plot(np.fft.ifft(fft_list_m10), label='Fourier transform with {} components'.format(num_))

plt.xlabel('Years')
plt.ylabel('Dollars per Million Btu')
plt.title('Natural Gas prices & Fourier transforms')
plt.legend()
plt.show()
# Out:
# C:\Users\Yasha\Anaconda3\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image
#from PIL import Image
from sklearn.tree import export_graphviz
import graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(dt, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
#graph.write_png("decision2.png")
#Image.open('decision2.png')
# Out:
# C:\Users\Yasha\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.237152 to fit
